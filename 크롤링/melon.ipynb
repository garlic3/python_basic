# %%
import selenium 
from selenium import webdriver
from bs4 import BeautifulSoup as bs

URL = 'https://www.melon.com/chart/index.htm'
driver = webdriver.Chrome('chromedriver.exe')
driver.get(URL)
html = driver.page_source
soup = bs(html)

songs = soup.select('tbody > tr')
song_data = []
rank = 1
for song in songs:
    title = song.select('div.rank01 > span > a')[0].text.strip()
    singer = song.select('div.rank02 > a')[0].text.strip()
    song_data.append([rank,title,singer])
    rank += 1

import pandas as pd
df = pd.DataFrame(song_data, columns = ['순위','타이틀','가수'])
df.to_excel('melon.xlsx',index=False)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_34940/1947001789.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')

# %%
df
# Out:
#      순위              타이틀            가수
# 0     1        사랑은 늘 도망가           임영웅
# 1     2             취중고백    김민석 (멜로망스)
# 2     3             INVU  태연 (TAEYEON)
# 3     4        Step Back  GOT the beat
# 4     5           ELEVEN     IVE (아이브)
# ..  ...              ...           ...
# 95   96  비가 오는 날엔 (2021)   헤이즈 (Heize)
# 96   97   그날에 나는 맘이 편했을까           이예준
# 97   98     Life Goes On         방탄소년단
# 98   99         Timeless  태연 (TAEYEON)
# 99  100            Siren  태연 (TAEYEON)
#
# [100 rows x 3 columns]
